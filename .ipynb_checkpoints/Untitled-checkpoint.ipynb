# %%
# show plots in notebook workspace
# %matplotlib inline
# import libraries
import warnings
import numpy as np
import matplotlib.pyplot as plt
# do not show warnings
warnings.filterwarnings('ignore')
# define plot layout
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = 15,6
#plt.rcParams['axes.titlepad'] = 10

# %%
def function(x,a=1.,b=0.,c=0.):
    y = a*x**2 + b*x + c
    return y

# %%
# set variables
a=1;b=1;c=0
# set variablex and calculate function values y
x = [-1.,-0.5,0.,0.5,1.]
x = np.linspace(-1.,1.,11)
y = function(x,a,b,c)

print ('x: ',x)
print ('y: ',y)
# plot results
plt.plot(x,y)
# Out:
# x:  [-1.  -0.8 -0.6 -0.4 -0.2  0.   0.2  0.4  0.6  0.8  1. ]
# y:  [ 0.   -0.16 -0.24 -0.24 -0.16  0.    0.24  0.56  0.96  1.44  2.  ]

# %%
xl = -1.
xu = 1.
xinc=0.1
xspace = np.arange(xl, xu + xinc, xinc)
for i,x in enumerate(xspace):
    print (i,x)
