# %% [markdown]
# <table>
# <tr><td><img style="height: 150px;" src="images/geo_hydro1.jpg"></td>
# <td bgcolor="#FFFFFF">
#     <p style="font-size: xx-large; font-weight: 900; line-height: 100%">AG Dynamics of the Earth</p>
#     <p style="font-size: large; color: rgba(0,0,0,0.5);">Jupyter notebooks</p>
#     <p style="font-size: large; color: rgba(0,0,0,0.5);">Georg Kaufmann</p>
#     </td>
# </tr>
# </table>

# %% [markdown]
# # Numerical methods: 11. Finite differences
# ## Analytical solution of 2D Laplace equation
# ----
# *Georg Kaufmann,
# Geophysics Section,
# Institute of Geological Sciences,
# Freie Universität Berlin,
# Germany*

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2D Laplace equation
#
# We seek solutions of the Laplace equation for the 2D field $c(x,y)$:
# $$
#  \frac{\partial^2 c}{\partial x^2} + \frac{\partial^2 c}{\partial y^2} = 0
# $$
# - $x$ [m] coordinate
# - $y$ [m] coordinate
#
# for a set of boundary conditions:
# $$
# \begin{array}{rcl}
#  c(0,y) &=& 0 \\
#  c(x,0) &=& 0 \\
#  c(a,y) &=& \sinh(x) \\
#  c(x,b) &=& \sin(y)
# \end{array}
# $$
#
# Solutions are:
# $$
# c(x,y) = \sinh(\lambda x) \sin(\lambda y)
# $$
# with $\lambda$ an eigenvalue.

# %%
x = np.linspace(-3,3,101)
plt.plot(x,np.sinh(x),label='sinh')
plt.plot(x,np.cosh(x),label='cosh')
plt.legend()
plt.grid()

# %%
a = np.pi
b = 3*np.pi

nx=100;ny=50
x=np.linspace(0,a,nx)
y=np.linspace(0,b,ny)

# %%
upper = np.sinh(x)
right = np.sin(y)

# %%
# %matplotlib inline
fig,ax = plt.subplots(1,2)
ax[0].plot(x,upper)
ax[1].plot(y,right)

# %%
lamb=1
X,Y = np.meshgrid(x,y)
U = np.sinh(lamb*X) * np.sin(lamb*Y)
print(U.shape,U.max())
U=U/U.max()
# Out:
# (50, 100) 11.54280580207351

# %%
# %matplotlib inline
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(projection='3d')
ax.set_title('Laplace equation ($\lambda=$'+str(lamb)+')')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('c')
ax.plot_surface(X,Y,U)

# %%
lamb=2
X,Y = np.meshgrid(x,y)
U = np.sinh(lamb*X) * np.sin(lamb*Y)
print(U.shape,U.max())
U=U/U.max()
# Out:
# (50, 100) 267.6073310521096

# %%
# %matplotlib notebook
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(projection='3d')
ax.set_title('Laplace equation ($\lambda=$'+str(lamb)+')')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('c')
ax.plot_surface(X,Y,U)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# [from](https://www.youtube.com/watch?v=2aJ3fFwET68)

# %% [markdown]
# ----
